# %% [markdown]
# # This is an English Premier League (EPL) Match Prediction System

# %%
# let's import our libraries 

import pandas as pd

# %%
epl_system = pd.read_csv('data/epl_final.csv')
# Out:
# Running cells with 'epl-prediction-system (3.14.6) (Python 3.14.6)' requires the ipykernel package.
#
# Install 'ipykernel' into the Python environment.
#
# Command: '"c:/Users/Michael Ugwumba/OneDrive/Desktop/RESUME PROJECTS/epl-prediction-system/.venv/Scripts/python.exe" -m pip install ipykernel -U --force-reinstall'

# %%
epl_system.head()
